# %% [markdown]
# ## Soltion 1: Using list(with min())

# %%
class MinStack(object):
    def __init__(self):
        self.stack = []

    def push(self, value):
        """
        :type value: int
        :rtype: None
        """
        self.stack.append(value)
        

    def pop(self):
        """
        :rtype: None
        """
        self.stack.pop()

    def top(self):
        """
        :rtype: int
        """
        return self.stack[-1]

    def getMin(self):
        """
        :rtype: int
        """
        return min(self.stack) 

    def showStack(self):
        print(self.stack)

stack = MinStack()
stack.push(-2)
stack.push(0)
stack.push(-3)
stack.showStack()
print(stack.getMin())
stack.pop()
print(stack.top())
print(stack.getMin())

# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(value)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()
# Out:
# [-2, 0, -3]
# -3
# 0
# -2

# %% [markdown]
# **push()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
#
# **pop()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
#
# **top()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
#
# **getMin()**
#
# Time Complexity: $O(n)$
# Space Complexity: $O(1)$

# %% [markdown]
# ## Solution 2: Using node with val and min

# %%
class Node(object):
    def __init__(self, val, min):
        self.val = val
        self.min = min

class MinStack(object):
    def __init__(self):
        self.stack = []

    def push(self, value):
        """
        :type value: int
        :rtype: None
        """
        if len(self.stack) == 0:
            node = Node(value, value)
            self.stack.append(node)

        else: 
            node = Node(value, min(self.stack[-1].min, value))
            self.stack.append(node)
        

    def pop(self):
        """
        :rtype: None
        """
        self.stack.pop()

    def top(self):
        """
        :rtype: int
        """
        return self.stack[-1].val

    def getMin(self):
        """
        :rtype: int
        """
        return self.stack[-1].min

    def showStack(self):
        for node in self.stack:
            print((node.val, node.min))

stack = MinStack()
stack.push(-2)
stack.push(0)
stack.push(-3)
stack.showStack()
print(stack.getMin())
stack.pop()
print(stack.top())
print(stack.getMin())

# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(value)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()
# Out:
# (-2, -2)
# (0, -2)
# (-3, -3)
# -3
# 0
# -2

# %% [markdown]
# **push()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
#
# **pop()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
#
# **top()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
#
# **getMin()**
#
# Time Complexity: $O(1)$
# Space Complexity: $O(1)$
