# %%
class Node:
    def __init__(self, x):
        self.val = x
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def append(self, data):
        if self.head == None:
            self.head = Node(data)
        else:
            current_node = self.head
            while current_node.next:
                current_node = current_node.next
            current_node.next = Node(data)
    
    def display(self):
        list_emp = []
        current_node = self.head
        while current_node:
            list_emp.append(str(current_node.val))
            current_node = current_node.next
        print(' -> '.join(list_emp))

# %% [markdown]
# ## Solution 1: Use Two pointer (fast, slow)

# %%
head = [1,2,3,4]
n = 1

def removeNthFromEnd(head, n):
    linked_list = LinkedList()
    for i in head:
        linked_list.append(i)

    linked_list.display()
    dummy = Node(0)
    dummy.next = linked_list.head

    slow = dummy
    fast = dummy

    # define fast node
    for _ in range(n + 1):
        fast = fast.next
        
    # update slow, fast nodes
    while fast is not None:
        slow = slow.next
        fast = fast.next
    
    slow.next = slow.next.next
    linked_list.head = dummy.next
    linked_list.display()
    

removeNthFromEnd(head, n)
# Out:
# 1 -> 2 -> 3 -> 4
# 1 -> 2 -> 3

# %% [markdown]
# Time Complexity: $O(n)$
#
# Space Complexity: $O(1)$
